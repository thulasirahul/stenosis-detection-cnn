# %% [markdown]
# ## GOOGLE OR INCEPTION NET ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2.14.1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'datasets/train',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 1545 images belonging to 4 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'datasets/test',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 381 images belonging to 4 classes.

# %%
def googlenet(input_shape, n_classes):
  
  def inception_block(x, f):
    t1 = Conv2D(f[0], 1, activation='relu')(x)
    
    t2 = Conv2D(f[1], 1, activation='relu')(x)
    t2 = Conv2D(f[2], 3, padding='same', activation='relu')(t2)
    
    t3 = Conv2D(f[3], 1, activation='relu')(x)
    t3 = Conv2D(f[4], 5, padding='same', activation='relu')(t3)
    
    t4 = MaxPool2D(3, 1, padding='same')(x)
    t4 = Conv2D(f[5], 1, activation='relu')(t4)
    
    output = Concatenate()([t1, t2, t3, t4])
    return output
  
  
  input = Input(input_shape)
  
  x = Conv2D(64, 7, strides=2, padding='same', activation='relu')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  x = Conv2D(64, 1, activation='relu')(x)
  x = Conv2D(192, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(3, strides=2)(x)
  
  x = inception_block(x, [64, 96, 128, 16, 32, 32])
  x = inception_block(x, [128, 128, 192, 32, 96, 64])
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  x = inception_block(x, [192, 96, 208, 16, 48, 64])
  x = inception_block(x, [160, 112, 224, 24, 64, 64])
  x = inception_block(x, [128, 128, 256, 24, 64, 64])
  x = inception_block(x, [112, 144, 288, 32, 64, 64])
  x = inception_block(x, [256, 160, 320, 32, 128, 128])
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = inception_block(x, [256, 160, 320, 32, 128, 128])
  x = inception_block(x, [384, 192, 384, 48, 128, 128])
  
  x = AvgPool2D(7, strides=1)(x)
  x = Dropout(0.4)(x)
  
  x = Flatten()(x)
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 4

K.clear_session()
model = googlenet(input_shape, n_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)           4160      ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 192)          110784    ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 27, 27, 192)          0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 96)           18528     ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 16)           3088      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 27, 27, 192)          0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 64)           12352     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 27, 27, 128)          110720    ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 27, 27, 32)           12832     ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 27, 27, 32)           6176      ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 27, 27, 256)          0         ['conv2d_3[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 27, 27, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 27, 27, 32)           8224      ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 27, 27, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 192)          221376    ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 27, 27, 96)           76896     ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 27, 27, 64)           16448     ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 27, 27, 480)          0         ['conv2d_9[0][0]',
#  )                                                                   'conv2d_11[0][0]',
#                                                                      'conv2d_13[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 480)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 96)           46176     ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 16)           7696      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 480)          0         ['max_pooling2d_4[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 192)          92352     ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 208)          179920    ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 48)           19248     ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 64)           30784     ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_15[0][0]',
#  )                                                                   'conv2d_17[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 160)          82080     ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 224)          226016    ['conv2d_22[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_21[0][0]',
#  )                                                                   'conv2d_23[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 256)          295168    ['conv2d_28[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_27[0][0]',
#  )                                                                   'conv2d_29[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 144)          73872     ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 32)           16416     ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_4[0][0]']
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 288)          373536    ['conv2d_34[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 64)           51264     ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate  (None, 14, 14, 528)          0         ['conv2d_33[0][0]',
#  )                                                                   'conv2d_35[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 160)          84640     ['concatenate_5[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 32)           16928     ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 528)          0         ['concatenate_5[0][0]']
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 256)          135424    ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 320)          461120    ['conv2d_40[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 128)          102528    ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 128)          67712     ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate  (None, 14, 14, 832)          0         ['conv2d_39[0][0]',
#  )                                                                   'conv2d_41[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_6[0][0]']
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 7, 7, 160)            133280    ['max_pooling2d_10[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 7, 7, 32)             26656     ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_10[0][0]']
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 7, 7, 256)            213248    ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 320)            461120    ['conv2d_46[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 7, 7, 128)            102528    ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate  (None, 7, 7, 832)            0         ['conv2d_45[0][0]',
#  )                                                                   'conv2d_47[0][0]',
#                                                                      'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 7, 7, 192)            159936    ['concatenate_7[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 7, 7, 48)             39984     ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 7, 7, 384)            319872    ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 7, 7, 384)            663936    ['conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 128)            153728    ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_12[0][0]']
#
#  concatenate_8 (Concatenate  (None, 7, 7, 1024)           0         ['conv2d_51[0][0]',
#  )                                                                   'conv2d_53[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 1024)           0         ['concatenate_8[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)           0         ['average_pooling2d[0][0]']
#
#  flatten (Flatten)           (None, 1024)                 0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 4)                    4100      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 5977652 (22.80 MB)
# Trainable params: 5977652 (22.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model_path = "GOOGLE.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 50
batch_size = 64

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3845 - accuracy: 0.3086 - precision: 0.0000e+00
# Epoch 1: accuracy improved from -inf to 0.30859, saving model to GOOGLE.h5
# 24/24 [==============================] - 135s 5s/step - loss: 1.3845 - accuracy: 0.3086 - precision: 0.0000e+00 - val_loss: 1.4012 - val_accuracy: 0.1813 - val_precision: 0.0000e+00
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3734 - accuracy: 0.3255 - precision: 0.0000e+00
# Epoch 2: accuracy improved from 0.30859 to 0.32552, saving model to GOOGLE.h5
# 24/24 [==============================] - 118s 5s/step - loss: 1.3734 - accuracy: 0.3255 - precision: 0.0000e+00 - val_loss: 1.4021 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 3/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3730 - accuracy: 0.3281 - precision: 0.0000e+00
# Epoch 3: accuracy improved from 0.32552 to 0.32812, saving model to GOOGLE.h5
# 24/24 [==============================] - 115s 5s/step - loss: 1.3730 - accuracy: 0.3281 - precision: 0.0000e+00 - val_loss: 1.4063 - val_accuracy: 0.2000 - val_precision: 0.0000e+00
# Epoch 4/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3732 - accuracy: 0.3268 - precision: 0.0000e+00
# Epoch 4: accuracy did not improve from 0.32812
# 24/24 [==============================] - 127s 5s/step - loss: 1.3732 - accuracy: 0.3268 - precision: 0.0000e+00 - val_loss: 1.4035 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 5/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3745 - accuracy: 0.3262 - precision: 0.0000e+00
# Epoch 5: accuracy did not improve from 0.32812
# 24/24 [==============================] - 116s 5s/step - loss: 1.3745 - accuracy: 0.3262 - precision: 0.0000e+00 - val_loss: 1.3991 - val_accuracy: 0.2625 - val_precision: 0.0000e+00
# Epoch 6/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3779 - accuracy: 0.3099 - precision: 0.0000e+00
# Epoch 6: accuracy did not improve from 0.32812
# 24/24 [==============================] - 110s 5s/step - loss: 1.3779 - accuracy: 0.3099 - precision: 0.0000e+00 - val_loss: 1.4050 - val_accuracy: 0.2062 - val_precision: 0.0000e+00
# Epoch 7/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3780 - accuracy: 0.3060 - precision: 0.0000e+00
# Epoch 7: accuracy did not improve from 0.32812
# 24/24 [==============================] - 118s 5s/step - loss: 1.3780 - accuracy: 0.3060 - precision: 0.0000e+00 - val_loss: 1.3990 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 8/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3766 - accuracy: 0.3164 - precision: 0.0000e+00
# Epoch 8: accuracy did not improve from 0.32812
# 24/24 [==============================] - 117s 5s/step - loss: 1.3766 - accuracy: 0.3164 - precision: 0.0000e+00 - val_loss: 1.3982 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 9/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3718 - accuracy: 0.3294 - precision: 0.0000e+00
# Epoch 9: accuracy improved from 0.32812 to 0.32943, saving model to GOOGLE.h5
# 24/24 [==============================] - 131s 5s/step - loss: 1.3718 - accuracy: 0.3294 - precision: 0.0000e+00 - val_loss: 1.3977 - val_accuracy: 0.2562 - val_precision: 0.0000e+00
# Epoch 10/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3635 - accuracy: 0.3463 - precision: 0.0000e+00
# Epoch 10: accuracy improved from 0.32943 to 0.34631, saving model to GOOGLE.h5
# 24/24 [==============================] - 113s 5s/step - loss: 1.3635 - accuracy: 0.3463 - precision: 0.0000e+00 - val_loss: 1.4478 - val_accuracy: 0.1937 - val_precision: 0.0000e+00
# Epoch 11/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3852 - accuracy: 0.2956 - precision: 0.0000e+00
# Epoch 11: accuracy did not improve from 0.34631
# 24/24 [==============================] - 121s 5s/step - loss: 1.3852 - accuracy: 0.2956 - precision: 0.0000e+00 - val_loss: 1.3955 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 12/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3734 - accuracy: 0.3307 - precision: 0.0000e+00
# Epoch 12: accuracy did not improve from 0.34631
# 24/24 [==============================] - 131s 5s/step - loss: 1.3734 - accuracy: 0.3307 - precision: 0.0000e+00 - val_loss: 1.4054 - val_accuracy: 0.2250 - val_precision: 0.0000e+00
# Epoch 13/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3685 - accuracy: 0.3372 - precision: 0.0000e+00
# Epoch 13: accuracy did not improve from 0.34631
# 24/24 [==============================] - 116s 5s/step - loss: 1.3685 - accuracy: 0.3372 - precision: 0.0000e+00 - val_loss: 1.4139 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 14/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3722 - accuracy: 0.3275 - precision: 0.0000e+00
# Epoch 14: accuracy did not improve from 0.34631
# 24/24 [==============================] - 113s 5s/step - loss: 1.3722 - accuracy: 0.3275 - precision: 0.0000e+00 - val_loss: 1.4078 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 15/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3763 - accuracy: 0.3141 - precision: 0.0000e+00
# Epoch 15: accuracy did not improve from 0.34631
# 24/24 [==============================] - 124s 5s/step - loss: 1.3763 - accuracy: 0.3141 - precision: 0.0000e+00 - val_loss: 1.3946 - val_accuracy: 0.2438 - val_precision: 0.0000e+00
# Epoch 16/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3783 - accuracy: 0.3074 - precision: 0.0000e+00
# Epoch 16: accuracy did not improve from 0.34631
# 24/24 [==============================] - 107s 4s/step - loss: 1.3783 - accuracy: 0.3074 - precision: 0.0000e+00 - val_loss: 1.4048 - val_accuracy: 0.2250 - val_precision: 0.0000e+00
# Epoch 17/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3706 - accuracy: 0.3320 - precision: 0.0000e+00
# Epoch 17: accuracy did not improve from 0.34631
# 24/24 [==============================] - 115s 5s/step - loss: 1.3706 - accuracy: 0.3320 - precision: 0.0000e+00 - val_loss: 1.4174 - val_accuracy: 0.2062 - val_precision: 0.0000e+00
# Epoch 18/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3645 - accuracy: 0.3477 - precision: 0.0000e+00
# Epoch 18: accuracy improved from 0.34631 to 0.34766, saving model to GOOGLE.h5
# 24/24 [==============================] - 117s 5s/step - loss: 1.3645 - accuracy: 0.3477 - precision: 0.0000e+00 - val_loss: 1.4007 - val_accuracy: 0.2625 - val_precision: 0.0000e+00
# Epoch 19/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3753 - accuracy: 0.3208 - precision: 0.0000e+00
# Epoch 19: accuracy did not improve from 0.34766
# 24/24 [==============================] - 114s 5s/step - loss: 1.3753 - accuracy: 0.3208 - precision: 0.0000e+00 - val_loss: 1.4085 - val_accuracy: 0.2188 - val_precision: 0.0000e+00
# Epoch 20/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3715 - accuracy: 0.3275 - precision: 0.0000e+00
# Epoch 20: accuracy did not improve from 0.34766
# 24/24 [==============================] - 125s 5s/step - loss: 1.3715 - accuracy: 0.3275 - precision: 0.0000e+00 - val_loss: 1.4021 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 21/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3747 - accuracy: 0.3190 - precision: 0.0000e+00
# Epoch 21: accuracy did not improve from 0.34766
# 24/24 [==============================] - 134s 6s/step - loss: 1.3747 - accuracy: 0.3190 - precision: 0.0000e+00 - val_loss: 1.4115 - val_accuracy: 0.2062 - val_precision: 0.0000e+00
# Epoch 22/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3789 - accuracy: 0.3086 - precision: 0.0000e+00
# Epoch 22: accuracy did not improve from 0.34766
# 24/24 [==============================] - 118s 5s/step - loss: 1.3789 - accuracy: 0.3086 - precision: 0.0000e+00 - val_loss: 1.4105 - val_accuracy: 0.2125 - val_precision: 0.0000e+00
# Epoch 23/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3751 - accuracy: 0.3235 - precision: 0.0000e+00
# Epoch 23: accuracy did not improve from 0.34766
# 24/24 [==============================] - 108s 4s/step - loss: 1.3751 - accuracy: 0.3235 - precision: 0.0000e+00 - val_loss: 1.3985 - val_accuracy: 0.2562 - val_precision: 0.0000e+00
# Epoch 24/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3794 - accuracy: 0.3101 - precision: 0.0000e+00
# Epoch 24: accuracy did not improve from 0.34766
# 24/24 [==============================] - 109s 5s/step - loss: 1.3794 - accuracy: 0.3101 - precision: 0.0000e+00 - val_loss: 1.3946 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 25/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3772 - accuracy: 0.3128 - precision: 0.0000e+00
# Epoch 25: accuracy did not improve from 0.34766
# 24/24 [==============================] - 119s 5s/step - loss: 1.3772 - accuracy: 0.3128 - precision: 0.0000e+00 - val_loss: 1.4071 - val_accuracy: 0.2125 - val_precision: 0.0000e+00
# Epoch 26/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3777 - accuracy: 0.3087 - precision: 0.0000e+00
# Epoch 26: accuracy did not improve from 0.34766
# 24/24 [==============================] - 127s 5s/step - loss: 1.3777 - accuracy: 0.3087 - precision: 0.0000e+00 - val_loss: 1.4024 - val_accuracy: 0.2250 - val_precision: 0.0000e+00
# Epoch 27/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3683 - accuracy: 0.3369 - precision: 0.0000e+00
# Epoch 27: accuracy did not improve from 0.34766
# 24/24 [==============================] - 113s 5s/step - loss: 1.3683 - accuracy: 0.3369 - precision: 0.0000e+00 - val_loss: 1.3994 - val_accuracy: 0.2688 - val_precision: 0.0000e+00
# Epoch 28/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3808 - accuracy: 0.2995 - precision: 0.0000e+00
# Epoch 28: accuracy did not improve from 0.34766
# 24/24 [==============================] - 118s 5s/step - loss: 1.3808 - accuracy: 0.2995 - precision: 0.0000e+00 - val_loss: 1.4250 - val_accuracy: 0.1750 - val_precision: 0.0000e+00
# Epoch 29/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3742 - accuracy: 0.3229 - precision: 0.0000e+00
# Epoch 29: accuracy did not improve from 0.34766
# 24/24 [==============================] - 116s 5s/step - loss: 1.3742 - accuracy: 0.3229 - precision: 0.0000e+00 - val_loss: 1.4071 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 30/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3728 - accuracy: 0.3235 - precision: 0.0000e+00
# Epoch 30: accuracy did not improve from 0.34766
# 24/24 [==============================] - 109s 5s/step - loss: 1.3728 - accuracy: 0.3235 - precision: 0.0000e+00 - val_loss: 1.4029 - val_accuracy: 0.2438 - val_precision: 0.0000e+00
# Epoch 31/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3768 - accuracy: 0.3168 - precision: 0.0000e+00
# Epoch 31: accuracy did not improve from 0.34766
# 24/24 [==============================] - 113s 5s/step - loss: 1.3768 - accuracy: 0.3168 - precision: 0.0000e+00 - val_loss: 1.4036 - val_accuracy: 0.2250 - val_precision: 0.0000e+00
# Epoch 32/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3765 - accuracy: 0.3141 - precision: 0.0000e+00
# Epoch 32: accuracy did not improve from 0.34766
# 24/24 [==============================] - 112s 5s/step - loss: 1.3765 - accuracy: 0.3141 - precision: 0.0000e+00 - val_loss: 1.4075 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 33/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3794 - accuracy: 0.3101 - precision: 0.0000e+00
# Epoch 33: accuracy did not improve from 0.34766
# 24/24 [==============================] - 110s 5s/step - loss: 1.3794 - accuracy: 0.3101 - precision: 0.0000e+00 - val_loss: 1.3946 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 34/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3724 - accuracy: 0.3248 - precision: 0.0000e+00
# Epoch 34: accuracy did not improve from 0.34766
# 24/24 [==============================] - 108s 4s/step - loss: 1.3724 - accuracy: 0.3248 - precision: 0.0000e+00 - val_loss: 1.4031 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 35/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3726 - accuracy: 0.3262 - precision: 0.0000e+00
# Epoch 35: accuracy did not improve from 0.34766
# 24/24 [==============================] - 112s 5s/step - loss: 1.3726 - accuracy: 0.3262 - precision: 0.0000e+00 - val_loss: 1.3998 - val_accuracy: 0.2438 - val_precision: 0.0000e+00
# Epoch 36/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3749 - accuracy: 0.3177 - precision: 0.0000e+00
# Epoch 36: accuracy did not improve from 0.34766
# 24/24 [==============================] - 120s 5s/step - loss: 1.3749 - accuracy: 0.3177 - precision: 0.0000e+00 - val_loss: 1.4119 - val_accuracy: 0.2062 - val_precision: 0.0000e+00
# Epoch 37/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3679 - accuracy: 0.3385 - precision: 0.0000e+00
# Epoch 37: accuracy did not improve from 0.34766
# 24/24 [==============================] - 117s 5s/step - loss: 1.3679 - accuracy: 0.3385 - precision: 0.0000e+00 - val_loss: 1.4317 - val_accuracy: 0.1688 - val_precision: 0.0000e+00
# Epoch 38/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3771 - accuracy: 0.3138 - precision: 0.0000e+00
# Epoch 38: accuracy did not improve from 0.34766
# 24/24 [==============================] - 117s 5s/step - loss: 1.3771 - accuracy: 0.3138 - precision: 0.0000e+00 - val_loss: 1.4007 - val_accuracy: 0.2438 - val_precision: 0.0000e+00
# Epoch 39/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3758 - accuracy: 0.3164 - precision: 0.0000e+00
# Epoch 39: accuracy did not improve from 0.34766
# 24/24 [==============================] - 113s 5s/step - loss: 1.3758 - accuracy: 0.3164 - precision: 0.0000e+00 - val_loss: 1.4186 - val_accuracy: 0.1937 - val_precision: 0.0000e+00
# Epoch 40/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3673 - accuracy: 0.3383 - precision: 0.0000e+00
# Epoch 40: accuracy did not improve from 0.34766
# 24/24 [==============================] - 114s 5s/step - loss: 1.3673 - accuracy: 0.3383 - precision: 0.0000e+00 - val_loss: 1.4210 - val_accuracy: 0.2000 - val_precision: 0.0000e+00
# Epoch 41/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3752 - accuracy: 0.3151 - precision: 0.0000e+00
# Epoch 41: accuracy did not improve from 0.34766
# 24/24 [==============================] - 113s 5s/step - loss: 1.3752 - accuracy: 0.3151 - precision: 0.0000e+00 - val_loss: 1.4087 - val_accuracy: 0.2250 - val_precision: 0.0000e+00
# Epoch 42/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3755 - accuracy: 0.3216 - precision: 0.0000e+00
# Epoch 42: accuracy did not improve from 0.34766
# 24/24 [==============================] - 115s 5s/step - loss: 1.3755 - accuracy: 0.3216 - precision: 0.0000e+00 - val_loss: 1.4072 - val_accuracy: 0.2313 - val_precision: 0.0000e+00
# Epoch 43/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3755 - accuracy: 0.3151 - precision: 0.0000e+00
# Epoch 43: accuracy did not improve from 0.34766
# 24/24 [==============================] - 117s 5s/step - loss: 1.3755 - accuracy: 0.3151 - precision: 0.0000e+00 - val_loss: 1.3985 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 44/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3736 - accuracy: 0.3235 - precision: 0.0000e+00
# Epoch 44: accuracy did not improve from 0.34766
# 24/24 [==============================] - 112s 5s/step - loss: 1.3736 - accuracy: 0.3235 - precision: 0.0000e+00 - val_loss: 1.4022 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 45/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3726 - accuracy: 0.3242 - precision: 0.0000e+00
# Epoch 45: accuracy did not improve from 0.34766
# 24/24 [==============================] - 116s 5s/step - loss: 1.3726 - accuracy: 0.3242 - precision: 0.0000e+00 - val_loss: 1.4159 - val_accuracy: 0.1937 - val_precision: 0.0000e+00
# Epoch 46/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3750 - accuracy: 0.3208 - precision: 0.0000e+00
# Epoch 46: accuracy did not improve from 0.34766
# 24/24 [==============================] - 108s 5s/step - loss: 1.3750 - accuracy: 0.3208 - precision: 0.0000e+00 - val_loss: 1.4016 - val_accuracy: 0.2375 - val_precision: 0.0000e+00
# Epoch 47/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3768 - accuracy: 0.3151 - precision: 0.0000e+00
# Epoch 47: accuracy did not improve from 0.34766
# 24/24 [==============================] - 110s 5s/step - loss: 1.3768 - accuracy: 0.3151 - precision: 0.0000e+00 - val_loss: 1.3931 - val_accuracy: 0.2625 - val_precision: 0.0000e+00
# Epoch 48/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3759 - accuracy: 0.3164 - precision: 0.0000e+00
# Epoch 48: accuracy did not improve from 0.34766
# 24/24 [==============================] - 106s 4s/step - loss: 1.3759 - accuracy: 0.3164 - precision: 0.0000e+00 - val_loss: 1.3968 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 49/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3762 - accuracy: 0.3154 - precision: 0.0000e+00
# Epoch 49: accuracy did not improve from 0.34766
# 24/24 [==============================] - 111s 5s/step - loss: 1.3762 - accuracy: 0.3154 - precision: 0.0000e+00 - val_loss: 1.3988 - val_accuracy: 0.2438 - val_precision: 0.0000e+00
# Epoch 50/50
# 24/24 [==============================] - ETA: 0s - loss: 1.3707 - accuracy: 0.3275 - precision: 0.0000e+00
# Epoch 50: accuracy did not improve from 0.34766
# 24/24 [==============================] - 114s 5s/step - loss: 1.3707 - accuracy: 0.3275 - precision: 0.0000e+00 - val_loss: 1.4145 - val_accuracy: 0.2062 - val_precision: 0.0000e+00

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
