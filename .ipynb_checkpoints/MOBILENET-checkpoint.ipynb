# %%
import numpy as np
import pandas as pd
import io
import os
from matplotlib import image as mpimg
import matplotlib.pyplot as plt
import seaborn
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory  
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\SPIRO25\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# WARNING:tensorflow:From C:\Users\SPIRO25\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Explore Data

# %%
data_dir = 'Dataset'
labels = os.listdir(data_dir)
labels
# Out:
# ['cloudy', 'desert', 'green_area', 'water']

# %%
train_dataset = image_dataset_from_directory('../input/satellite-image-classification/data',
                                             shuffle=True,
                                             batch_size=32,image_size=(224,224))
class_name =  train_dataset.class_names
plt.figure(figsize = (10,10))
for image , label in train_dataset.take(1):
    for i in range(9) :
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(class_name[label[i]])
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_dataset = image_dataset_from_directory('../input/satellite-image-classification/data',
#       2                                              shuffle=True,
#       3                                              batch_size=32,image_size=(224,224))
#       4 class_name =  train_dataset.class_names
#       5 plt.figure(figsize = (10,10))
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_dataset.py:213, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     211 if seed is None:
#     212     seed = np.random.randint(1e6)
# --> 213 image_paths, labels, class_names = dataset_utils.index_directory(
#     214     directory,
#     215     labels,
#     216     formats=ALLOWLIST_FORMATS,
#     217     class_names=class_names,
#     218     shuffle=shuffle,
#     219     seed=seed,
#     220     follow_links=follow_links,
#     221 )
#     223 if label_mode == "binary" and len(class_names) != 2:
#     224     raise ValueError(
#     225         'When passing `label_mode="binary"`, there must be exactly 2 '
#     226         f"class_names. Received: class_names={class_names}"
#     227     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\dataset_utils.py:542, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#     540 else:
#     541     subdirs = []
# --> 542     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     543         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     544             if not subdir.startswith("."):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)
#     765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory ../input/satellite-image-classification/data

# %%
img_width, img_height = 224, 224
target_size = (img_width,img_height)
batch_size = 32

# %%
#Create a data generator for image augmentation
datagen = ImageDataGenerator( samplewise_center=True,  # set each sample mean to 0
                             rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                             zoom_range = 0.1, # Randomly zoom imag
                             width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                             height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                             horizontal_flip=True,  # randomly flip images
                             vertical_flip=False,
                             rescale=1./255,#scale images
                             validation_split=0.2) #split data, 80% for training and 20% for testing


#create training set from folders
train_data=datagen.flow_from_directory(data_dir,
                                       target_size=(target_size),
                                       batch_size=batch_size,
                                       class_mode='categorical',
                                       shuffle=True,subset='training')

#create test set
test_data=datagen.flow_from_directory(data_dir,
                                       target_size=(target_size),
                                       batch_size=batch_size,
                                      class_mode='categorical',
                                       shuffle=False,subset='validation')
# Out:
# Found 4505 images belonging to 4 classes.
# Found 1126 images belonging to 4 classes.

# %% [markdown]
# ## Evaluation Functions

# %%
def learning_curves(history):
    #plot the result
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)

    #accuracy plot
    plt.plot(epochs, acc, color='green', label='Training Accuracy')
    plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    plt.figure()
    #loss plot
    plt.plot(epochs, loss, color='pink', label='Training Loss')
    plt.plot(epochs, val_loss, color='red', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
def get_predections(model):
    # Generate predictions on the test set
    y_pred = model.predict(test_data)

    # Compute the confusion matrix
    y_true = test_data.classes
    y_pred = tf.argmax(y_pred, axis=1)
    return y_true,y_pred
    
def show_confusion_matrix(y_true,y_pred):
    cm  = confusion_matrix(y_pred,y_true)
    df_cm = pd.DataFrame(cm, index =   ["cloud","desert" ,'green_area', 'water'],
                  columns = ["cloud","desert" ,'green_area', 'water'])

    seaborn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
    plt.title('confusion matrix')
    plt.ylabel('prediction')
    plt.xlabel('Actual')
    plt.show()
    
def print_classification_report(y_true,y_pred):
    target_names = ["cloud","desert" ,'green_area', 'water']
    print(classification_report(y_true, y_pred, target_names=target_names))

# %% [markdown]
# ## VGG19 based model

# %%
from tensorflow.keras.applications.vgg19 import VGG19

vgg_base_model =  VGG19(include_top=True , weights='imagenet')
for layer in vgg_base_model.layers:
    layer.trainable= False

# %% [markdown]
# Load the vgg19 model from keras

# %%
vgg_base_model = tf.keras.Model(inputs=vgg_base_model.input, outputs=vgg_base_model.layers[-2].output)
vgg_model = tf.keras.Sequential()
for layer in vgg_base_model.layers:
    vgg_model.add(layer)

vgg_model.add(tf.keras.layers.Dense(4, activation='softmax'))

# %% [markdown]
# copy vgg layers and add top layer

# %%
vgg_model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
vgg_history = vgg_model.fit(train_data,
    validation_data = test_data, 
    callbacks = [early],
    epochs = 50)

# %%
vgg_model.evaluate(test_data)

# %% [markdown]
# ## MobileNet

# %% [markdown]
# ### 1 layer

# %%
mobile_base_model = tf.keras.applications.MobileNet()
for layer in mobile_base_model.layers:
    layer.trainable= False

# %% [markdown]
# ### 3 layers

# %%
mobile_base_model = tf.keras.applications.MobileNet()
for layer in mobile_base_model.layers[:-3]:
    layer.trainable= False

# %% [markdown]
# ### 5 layers

# %%
mobile_base_model = tf.keras.applications.MobileNet()
for layer in mobile_base_model.layers[:-5]:
    layer.trainable= False

# %% [markdown]
# #### model build

# %%
mobile_base_model = tf.keras.Model(inputs=mobile_base_model.input, outputs=mobile_base_model.layers[-2].output)

mobile_model = tf.keras.Sequential()

for layer in mobile_base_model.layers:
    mobile_model.add(layer)
    
mobile_model.add(tf.keras.layers.Dense(4, activation='softmax'))

# %% [markdown]
# #### Adam optimizer

# %%
mobile_model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
mobile_history = mobile_model.fit(train_data,
    validation_data = test_data, 
#     callbacks = [early],
    epochs = 40)
# Out:
# Epoch 1/40
# 141/141 [==============================] - 61s 434ms/step - loss: 0.0577 - accuracy: 0.9845 - val_loss: 0.1018 - val_accuracy: 0.9813
# Epoch 2/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0501 - accuracy: 0.9869 - val_loss: 0.0786 - val_accuracy: 0.9769
# Epoch 3/40
# 141/141 [==============================] - 62s 438ms/step - loss: 0.0651 - accuracy: 0.9831 - val_loss: 0.1160 - val_accuracy: 0.9742
# Epoch 4/40
# 141/141 [==============================] - 64s 451ms/step - loss: 0.0332 - accuracy: 0.9913 - val_loss: 0.0849 - val_accuracy: 0.9840
# Epoch 5/40
# 141/141 [==============================] - 63s 445ms/step - loss: 0.0566 - accuracy: 0.9880 - val_loss: 0.0485 - val_accuracy: 0.9902
# Epoch 6/40
# 141/141 [==============================] - 62s 437ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.0486 - val_accuracy: 0.9876
# Epoch 7/40
# 141/141 [==============================] - 61s 435ms/step - loss: 0.0272 - accuracy: 0.9911 - val_loss: 0.0453 - val_accuracy: 0.9893
# Epoch 8/40
# 141/141 [==============================] - 61s 436ms/step - loss: 0.0334 - accuracy: 0.9911 - val_loss: 0.0491 - val_accuracy: 0.9920
# Epoch 9/40
# 141/141 [==============================] - 62s 442ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.0346 - val_accuracy: 0.9893
# Epoch 10/40
# 141/141 [==============================] - 61s 435ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0767 - val_accuracy: 0.9885
# Epoch 11/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0182 - accuracy: 0.9949 - val_loss: 0.0462 - val_accuracy: 0.9911
# Epoch 12/40
# 141/141 [==============================] - 62s 437ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0
y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        cloud       1.00      1.00      1.00       300
#       desert       1.00      1.00      1.00       226
#   green_area       0.99      0.99      0.99       300
#        water       0.99      0.99      0.99       300
#
#     accuracy                           0.99      1126
#    macro avg       0.99      0.99      0.99      1126
# weighted avg       0.99      0.99      0.99      1126

# %% [markdown]
# #### SGD optimizer

# %%
mobile_model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
mobile_history = mobile_model.fit(train_data,
    validation_data = test_data, 
#     callbacks = [early],
    epochs = 40)
# Out:
# Epoch 1/40
# 2023-12-30 21:19:29.605576: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_3/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 141/141 [==============================] - 65s 447ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0649 - val_accuracy: 0.9902
# Epoch 2/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0733 - val_accuracy: 0.9902
# Epoch 3/40
# 141/141 [==============================] - 61s 433ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.0894 - val_accuracy: 0.9911
# Epoch 4/40
# 141/141 [==============================] - 62s 437ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0553 - val_accuracy: 0.9956
# Epoch 5/40
# 141/141 [==============================] - 62s 443ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0548 - val_accuracy: 0.9947
# Epoch 6/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0681 - val_accuracy: 0.9902
# Epoch 7/40
# 141/141 [==============================] - 61s 435ms/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 0.0585 - val_accuracy: 0.9893
# Epoch 8/40
# 141/141 [==============================] - 62s 437ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0572 - val_accuracy: 0.9920
# Epoch 9/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.0602 - val_accuracy: 0.9902
# Epoch 10/40
# 141/141 [==============================] - 64s 456ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0266 - val_accuracy: 0.9964
# Epoch 11/40
# 141/141 [==============================] - 63s 446ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0657 - val_accuracy: 0.9920
# Epoch 12/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0404 - val_accuracy: 0.9929
# Epoch 13/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.0571 - val_accuracy: 0.9920
# Epoch 14/40
# 141/141 [==============================] - 62s 438ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0424 - val_accuracy: 0.9947
# Epoch 15/40
# 141/141 [==============================] - 62s 442ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0757 - val_accuracy: 0.9920
# Epoch 16/40
# 141/141 [==============================] - 62s 438ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0411 - val_accuracy: 0.9938
# Epoch 17/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.0403 - val_accuracy: 0.9938
# Epoch 18/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0599 - val_accuracy: 0.9920
# Epoch 19/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 0.0577 - val_accuracy: 0.9911
# Epoch 20/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0479 - val_accuracy: 0.9938
# Epoch 21/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0694 - val_accuracy: 0.9920
# Epoch 22/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.0435 - val_accuracy: 0.9920
# Epoch 23/40
# 141/141 [==============================] - 61s 436ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.0429 - val_accuracy: 0.9938
# Epoch 24/40
# 141/141 [==============================] - 62s 438ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.0610 - val_accuracy: 0.9920
# Epoch 25/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.0327 - val_accuracy: 0.9938
# Epoch 26/40
# 141/141 [==============================] - 63s 445ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0619 - val_accuracy: 0.9911
# Epoch 27/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.0459 - val_accuracy: 0.9938
# Epoch 28/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.0305 - val_accuracy: 0.9947
# Epoch 29/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0433 - val_accuracy: 0.9938
# Epoch 30/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0320 - val_accuracy: 0.9947
# Epoch 31/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0394 - val_accuracy: 0.9911
# Epoch 32/40
# 141/141 [==============================] - 62s 437ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0496 - val_accuracy: 0.9911
# Epoch 33/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0516 - val_accuracy: 0.9911
# Epoch 34/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0217 - val_accuracy: 0.9956
# Epoch 35/40
# 141/141 [==============================] - 63s 445ms/step - loss: 0.0041 - accuracy: 0.9982 - val_loss: 0.0481 - val_accuracy: 0.9929
# Epoch 36/40
# 141/141 [==============================] - 62s 440ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0584 - val_accuracy: 0.9885
# Epoch 37/40
# 141/141 [==============================] - 62s 438ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.0440 - val_accuracy: 0.9947
# Epoch 38/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0513 - val_accuracy: 0.9938
# Epoch 39/40
# 141/141 [==============================] - 62s 441ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0490 - val_accuracy: 0.9920
# Epoch 40/40
# 141/141 [==============================] - 62s 439ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0499 - val_accuracy: 0.9920

# %%
mobile_model.evaluate(test_data)
# Out:
# 36/36 [==============================] - 13s 355ms/step - loss: 0.0389 - accuracy: 0.9947
# [0.038887377828359604, 0.9946714043617249]

# %%
learning_curves(mobile_history)

# %%
y_true,y_pred = get_predections(mobile_model)
show_confusion_matrix(y_true,y_pred)
# Out:
# 36/36 [==============================] - 13s 341ms/step

# %%
print_classification_report(y_true,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        cloud       1.00      0.99      0.99       300
#       desert       1.00      1.00      1.00       226
#   green_area       0.99      0.98      0.99       300
#        water       0.98      0.99      0.98       300
#
#     accuracy                           0.99      1126
#    macro avg       0.99      0.99      0.99      1126
# weighted avg       0.99      0.99      0.99      1126

# %% [markdown]
# ## ResNet

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input

#Create a data generator for image augmentation
datagen = ImageDataGenerator( preprocessing_function=preprocess_input,
                             samplewise_center=True,  # set each sample mean to 0
                             rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                             zoom_range = 0.1, # Randomly zoom imag
                             width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                             height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                             horizontal_flip=True,  # randomly flip images
                             vertical_flip=False,
                             rescale=1./255,#scale images
                             validation_split=0.2) #split data, 80% for training and 20% for testing


#create training set from folders
train_data=datagen.flow_from_directory(data_dir,
                                       target_size=(target_size),
                                       batch_size=batch_size,
                                       class_mode='categorical',
                                       shuffle=True,subset='training')

#create test set
test_data=datagen.flow_from_directory(data_dir,
                                       target_size=(target_size),
                                       batch_size=batch_size,
                                      class_mode='categorical',
                                       shuffle=False,subset='validation')

# %%
from tensorflow.keras.applications import ResNet50

resnet_base_model = ResNet50(weights='imagenet', include_top=True)

for layer in resnet_base_model.layers:
    layer.trainable = False

# %%
x = resnet_base_model(resnet_base_model.input)
outputs = tf.keras.layers.Dense(4, activation='softmax')(x)

resnet_model = tf.keras.Model(inputs=resnet_base_model.input, outputs=outputs)

# %%
resnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
resnet_history = resnet_model.fit(train_data,
    validation_data = test_data, 
    callbacks = [early],
    epochs = 50)

# %%
resnet_model.evaluate(test_data)

# %% [markdown]
# ## Traditional Model

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu',input_shape=(244, 244, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),

    tf.keras.layers.Dense(4, activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
      train_data,
      validation_data = test_data, 
      epochs=50)

# %%
model.evaluate(test_data, steps=50)
